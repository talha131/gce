# %% [markdown]
# <a href="https://colab.research.google.com/github/talha131/gce/blob/master/Excel_Assignment_Data_Set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup Packages

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install numpy

import csv
import random
import os
from typing import List, Dict, Any
import logging
import numpy as np
from datetime import datetime

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s', force=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)

# %% [markdown]
# # Subject Pool

# %%
subjects_pool = [
    "Accounting",
    "Applied Chemistry",
    "Biology",
    "Business Studies",
    "Chemistry",
    "Child Development",
    "Child Psychology",
    "Classroom Assessment",
    "Classroom Management",
    "Communication Skills",
    "Comparative Education",
    "Compiler Construction",
    "Computer Literacy",
    "Computer Science",
    "Contemporary Issues",
    "Critical Thinking",
    "Curriculum Development",
    "Economics",
    "English Grammar",
    "English Literature",
    "Environmental Chemistry",
    "General Method of Teaching",
    "General Science",
    "Geography",
    "History",
    "Inclusive Education",
    "Information and Communication Technologies",
    "Inorganic Chemistry",
    "Introduction to Algorithm",
    "Islamic Studies",
    "Law",
    "Mathematics",
    "Organic Chemistry",
    "Pakistan Studies",
    "Philosophy",
    "Physics",
    "Principles of Commerce",
    "Psychology",
    "Research Methodology",
    "School Management",
    "School, Communities and Teachers",
    "Sindhi",
    "Sociology",
    "Statistics",
    "Teaching of English",
    "Teaching of Mathematics",
    "Teaching of Science",
    "Teaching of Urdu",
    "Test Development",
    "Theory of Automata",
    "Urdu Poetry",
    "Urdu",
    "Urdu Literature"
]

# %% [markdown]
# # Students Names

# %%
student_names = [
    "Aaiza Khan",
    "Aasma Raza",
    "Abdul Ahad Shah Warsi",
    "Abdul Aziz",
    "Abdul Basit Khan",
    "Abdul Latif",
    "Abdul Qadeer Khan",
    "Abdul Raheem",
    "Abdul Rahman",
    "Abdul Rasheed",
    "Abdul Razzaq",
    "Abdul Rehman",
    "Abdul Sajjad",
    "Abdul Sattar",
    "Abdul Tawwab",
    "Abdul Waheed",
    "Abdullah Siddiqui",
    "Abida Bano ",
    "Ahmed Zia Matloob",
    "Aiman",
    "Aiman Hassan",
    "Aiman Siddiqui",
    "Aisha",
    "Aisha Abdul Rasheed",
    "Aisha Aziz",
    "Akmal Khan",
    "Aleem Ahmed Khan",
    "Aleem Ullah",
    "Alia Kanwal",
    "Alif Khan Hassan Zai",
    "Aliza Saleem",
    "Allauddin",
    "Almas",
    "Alsa Baig",
    "Amjad Hussain",
    "Amna Abdul Rasheed",
    "Amna Usmani",
    "Aneela Batool",
    "Aneeqa Sirhandi",
    "Anis Ahmed Siddiqui",
    "Anosha Mukhtar",
    "Anshrah Zainab",
    "Anum",
    "Anum Mukhtar",
    "Anum Naz",
    "Anusha Javeed",
    "Aqsa Aslam",
    "Aqsa Jawed",
    "Aqsa Kanwal",
    "Aqsa Khan",
    "Areeba Abbas",
    "Areeba Ansari",
    "Ariba Saleem",
    "Asfia",
    "Ashhad Ul Hassan",
    "Ashiq Ali",
    "Asif Ahmed Khan",
    "Syeda Javeria Imran",
    "Syeda Kainat Jamshaid",
    "Syeda Kulsoom Abbas",
    "Syeda Mahe Umam",
    "Syeda Mahnoor Fatima",
    "Syeda Maliha",
    "Syeda Minhal Naqvi",
    "Syeda Saher Zeeshan",
    "Syeda Sani Zehra Rizvi",
    "Syeda Shiza Hassan Bukhari",
    "Syeda Tahreem Kazmi",
    "Syeda Wahid Ali",
    "Syeda Wajeeha Batool",
    "Syeda Zainab Abbas",
    "Tabina Sattar",
    "Tahir Hasan",
    "Tahira Iqbal",
    "Tahira Noor",
    "Tahsheem",
    "Talat Hashmi",
    "Talib Hussain",
    "Talib Rasool",
    "Tamkanat Khalid",
    "Tania",
    "Tariq Zahid",
    "Tasneem Yousuf",
    "Tauqir Hussain",
    "Tazeen Fatima",
    "Tehreem Khan",
    "Tooba Zafar",
    "Tooba Zia Khan",
    "Tuba Khan",
    "Tuba Moin",
    "Tuba Zehra",
    "Ummeha Bux",
    "Unzah Rais",
    "Unzila Masroor",
    "Urooba Kamal",
    "Waheed Ur Rehman",
    "Waqar Ahmed",
    "Warda Mehtab",
    "Warda Nadeem",
    "Warda Younas",
    "Wardah Saleem",
    "William",
    "Yamna Maqsood",
    "Yawar Abbas",
    "Yousuf Ali",
    "Yousuf Noman",
    "Yumna Mahmood",
    "Zafar Munir Ansari",
    "Zaheer Ud Din",
    "Zahid Akhtar",
    "Zahid Ali",
    "Zain Ul Abedin",
    "Zainab Ali",
    "Zainab Fatima",
    "Zakia Nazeer",
    "Zakia Nisar",
    "Zamir Ahmed Khan",
    "Zamir Uddin Qureshi",
    "Zara Akram",
    "Zarlashta",
    "Zawata",
    "Zeenat Bibi",
    "Zia Barkat",
    "Zohaib Ahmed Naseem",
    "Zubair Ahmed",
    "Zubair Khan",
    "Zubair Mohsin",
    "Zubia Ayaz",
    "Zulfiqar Ali",
    "Zunaira Aziz",
]

# %% [markdown]
# # Output

# %% [markdown]
# ## Output Directory

# %%
def ensure_output_directory(output_dir: str) -> None:
    """Ensure that the output directory exists, create it if it doesn't."""
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        logging.info(f"Created output directory: {output_dir}")

# %% [markdown]
# ## Generate CSV Files

# %%
def generate_csv_files(config: Dict[str, Any]) -> None:
    # Create a timestamped folder name
    timestamp = datetime.now().strftime("%Y-%m-%d %H%M")
    output_dir = f"/content/drive/My Drive/csv_output_{timestamp}"
    ensure_output_directory(output_dir)

    for i in range(config["num_files"]):
        num_students = random.randint(config["min_students"], config["max_students"])
        num_subjects = random.randint(config["min_subjects"], config["max_subjects"])
        subjects = random.sample(subjects_pool, num_subjects)

        selected_students = random.sample(
            student_names * ((num_students // len(student_names)) + 1), num_students
        )

        marks = generate_marks(num_students, num_subjects, config)

        file_name = f"{config['file_prefix']}{config['start_file_suffix'] + i}.csv"
        csv_file_path = os.path.join(output_dir, file_name)

        try:
            with open(csv_file_path, "w", newline="") as csvfile:
                csv_writer = csv.writer(csvfile)

                header = ["Name"] + subjects
                csv_writer.writerow(header)

                for idx, student_name in enumerate(selected_students):
                    csv_writer.writerow([student_name] + marks[idx])

            logging.info(f"Successfully generated {file_name}")
        except IOError as e:
            logging.error(f"Error writing to file {file_name}: {e}")

# %% [markdown]
# # Generate the Data

# %% [markdown]
# ## Generate Probabilities

# %%
def generate_probabilities(mean_prob: float, num: int, spread_factor: float) -> np.ndarray:
    """
    Generate an array of probabilities based on a mean and spread factor.

    :param mean_prob: The mean probability
    :param num: Number of probabilities to generate
    :param spread_factor: Controls the spread of probabilities around the mean
                          Higher values increase variability, lower values decrease it
    :return: Array of probabilities
    """
    std_dev = mean_prob * spread_factor
    probs = np.clip(np.random.normal(mean_prob, std_dev, num), 0, 1)
    return probs

# %% [markdown]
# ## Generate Marks

# %%
def generate_marks(num_students: int, num_subjects: int, config: Dict[str, Any]) -> List[List[str]]:
    marks_data = []

    absent_probs = generate_probabilities(config["absent_probability"], num_subjects, config["spread_factor"])

    student_types = config["student_types"]
    performance_params = config["performance_params"]

    for _ in range(num_students):
        student_type = np.random.choice(list(student_types.keys()), p=list(student_types.values()))
        row = []

        if student_type == 'high_performer':
            # High performers: rarely absent, mostly high scores
            for subject in range(num_subjects):
                if random.random() < absent_probs[subject] * 0.2:  # Much less likely to be absent
                    row.append("A")
                else:
                    mark = int(np.random.beta(performance_params["high"]["alpha"],
                                              performance_params["high"]["beta"]) * config["max_marks"])
                    row.append(str(mark))

        elif student_type == 'low_performer':
            # Low performers: more often absent, lower scores
            for subject in range(num_subjects):
                if random.random() < min(absent_probs[subject] * 2, 1):  # More likely to be absent
                    row.append(config["absent"])
                else:
                    mark = int(np.random.beta(performance_params["low"]["alpha"],
                                              performance_params["low"]["beta"]) * config["max_marks"])
                    row.append(str(mark))

        else:  # moderate performer
            # Moderate performers: mix of absences, low, and high scores
            for subject in range(num_subjects):
                if random.random() < absent_probs[subject]:
                    row.append(config["absent"])
                else:
                    if random.random() < 0.3:  # 30% chance of a high score
                        mark = int(np.random.beta(performance_params["high"]["alpha"],
                                                  performance_params["high"]["beta"]) * config["max_marks"])
                    elif random.random() < 0.3:  # 30% chance of a low score
                        mark = int(np.random.beta(performance_params["low"]["alpha"],
                                                  performance_params["low"]["beta"]) * config["max_marks"])
                    else:  # 40% chance of a moderate score
                        mark = int(np.random.beta(performance_params["moderate"]["alpha"],
                                                  performance_params["moderate"]["beta"]) * config["max_marks"])
                    row.append(str(mark))

        marks_data.append(row)

    return marks_data

# %% [markdown]
# # Configuration
#
# ### `absent_probability` (0.25)
#
# * This is the base probability for a student being absent in any given subject.
# * Increasing this value (e.g., to 0.4) will result in more absences across all student types.
# * Decreasing it (e.g., to 0.1) will result in fewer absences overall.
#
# ### `spread_factor` (0.75)
#
# * This controls the variability of absence probabilities across different subjects.
# * A higher value (e.g., 1.0) will create more diverse absence rates between subjects.
# * A lower value (e.g., 0.5) will make absence rates more uniform across subjects.
#
# ### `student_types`
#
# * These proportions determine the distribution of student types in the generated data.
# * Adjusting these will directly affect the overall performance distribution.
# * For example, increasing 'high_performer' will result in more high-scoring students overall.
#
# ### `performance_params`
#
# * These beta distribution parameters control the shape of the score distribution for each student type.
#
# #### For "high" performers
# * Increasing alpha (e.g., to 10) will push scores even higher.
# * Decreasing beta (e.g., to 1) will make very high scores more common.
#
# #### For "low" performers
#
# * Increasing beta (e.g., to 10) will push scores even lower.
# * Decreasing alpha (e.g., to 1) will make very low scores more common.
#
# #### For "moderate" performers
#
# * Keeping alpha and beta equal maintains a centered distribution.
# * Increasing both (e.g., to 7,7) will cluster scores more tightly around the middle.
# * Decreasing both (e.g., to 3,3) will spread scores out more evenly.
#
# ## Beta Distribution Shapes:
#
# 1. alpha > beta (skewed to higher scores)
#    e.g., alpha=8, beta=2
#
#    This creates a distribution skewed towards higher scores. Most scores will be in the upper range.
#
# ```
#      |    *
#      |   * *
#      |  *   *
#      | *     *
#      |*       *
#    __|*         *___
#      0    50    100   (Score)
# ```
#
# 2. alpha < beta (skewed to lower scores)
#    e.g., alpha=2, beta=8
#
#    This creates a distribution skewed towards lower scores. Most scores will be in the lower range.
#
# ```
#
#      |*
#      |*
#      | *
#      | *
#      |  *
#    __|   *_________*___
#      0    50    100   (Score)
#
# ```
#
# 3. alpha = beta (symmetric distribution)
#    e.g., alpha=5, beta=5
#
#    This creates a symmetric distribution centered at the midpoint (50 in this case).
#
#
# ```
#
#      |    *
#      |   * *
#      |  *   *
#      | *     *
#      |*       *
#    __|*_______*___
#      0    50    100   (Score)
#
# ```
#
# 4. Increasing both alpha and beta (more peaked)
#    e.g., alpha=10, beta=10
#
#    This makes the distribution more peaked around the center, meaning scores will be more clustered around the mean.
#
#
#   ```
#
#      |     *
#      |    * *
#      |   *   *
#      |  *     *
#      | *       *
#    __|*_________*___
#      0    50    100   (Score)
#
#   ```
#
# 5. Decreasing both alpha and beta (more spread out)
#    e.g., alpha=2, beta=2
#
#    This spreads out the distribution, making extreme scores (both high and low) more likely.
#
#
#
# ```
#
#      |
#      | *         *
#      |*           *
#      |*           *
#      |*           *
#    __|*___________*___
#      0    50    100   (Score)
#
# ```
#
#
# ### Legend
#
# * `*` represents the relative frequency of scores
# * `-` represents the x-axis (score range)
# * `|` represents the y-axis (frequency)

# %%
config = {
    # Prefix for the CSV file names
    "file_prefix": "2024 - Assignment 2 - A1-",

    # Starting number for the file suffix
    # Increasing this will start the file numbering from a higher value
    "start_file_suffix": 23136001,

    # Number of CSV files to generate
    # Increasing this will produce more files, decreasing will produce fewer
    "num_files": 105,

    # Minimum number of students per file
    # Increasing this will ensure more students in each file
    "min_students": 400,

    # Maximum number of students per file
    # Increasing this allows for potentially larger class sizes
    # The actual number of students will be randomly chosen between min and max
    "max_students": 600,

    # Minimum number of subjects per file
    # Increasing this ensures more subjects in each file
    "min_subjects": 20,

    # Maximum number of subjects per file
    # Increasing this allows for potentially more diverse subject lists
    # The actual number of subjects will be randomly chosen between min and max
    "max_subjects": 30,

    # Maximum marks for each subject
    # Changing this will affect the scale of the marks (e.g., 50 for a 50-point scale)
    "max_marks": 100,

    # Base probability of a student being absent
    # Increasing this will result in more absences overall
    # Decreasing will result in fewer absences
    "absent_probability": 0.25,

    # Factor controlling the spread of probabilities around the mean
    # Increasing this will create more variability in absent probabilities across subjects
    # Decreasing will make absent probabilities more uniform across subjects
    "spread_factor": 0.75,

    # Distribution of student types
    # Adjusting these values will change the proportion of each student type
    # Ensure these add up to 1.0
    "student_types": {
        'high_performer': 0.2,  # 20% high performers
        'low_performer': 0.3,   # 30% low performers
        'moderate': 0.5         # 50% moderate performers
    },

    # Parameters for the beta distribution used to generate marks for each performance level
    # alpha > beta skews distribution to higher scores
    # alpha < beta skews distribution to lower scores
    # alpha = beta creates a symmetric distribution
    # Increasing both alpha and beta makes the distribution more peaked
    # Decreasing both makes it more spread out
    "performance_params": {
        "high": {"alpha": 8, "beta": 2},  # Skewed towards high scores
        "low": {"alpha": 2, "beta": 8},   # Skewed towards low scores
        "moderate": {"alpha": 5, "beta": 5}  # Centered distribution
    },

    # String representation for absent students in the CSV
    # Changing this will affect how absences are recorded in the output files
    "absent": "Absent",
}

# %% [markdown]
# # Main

# %%
def main() -> None:
    try:
        generate_csv_files(config)
    except Exception as e:
        logging.exception("An unexpected error occurred:")

if __name__ == "__main__":
    main()
# Out:
# 2024-09-29 08:00:37,787 - INFO - Created output directory: /content/drive/My Drive/csv_output_2024-09-29 0800
# 2024-09-29 08:00:37,830 - INFO - Successfully generated 2024 - Assignment 2 - A1-23136001.csv
# 2024-09-29 08:00:37,880 - INFO - Successfully generated 2024 - Assignment 2 - A1-23136002.csv
# 2024-09-29 08:00:37,936 - INFO - Successfully generated 2024 - Assignment 2 - A1-23136003.csv
# 2024-09-29 08:00:37,990 - INFO - Successfully generated 2024 - Assignment 2 - A1-23136004.csv
# 2024-09-29 08:00:38,051 - INFO - Successfully generated 2024 - Assignment 2 - A1-23136005.csv
# 2024-09-29 08:00:38,115 - INFO - Successfully generated 2024 - Assignment 2 - A1-23136006.csv
# 2024-09-29 08:00:38,162 - INFO - Successfully generated 2024 - Assignment 2 - A1-23136007.csv
# 2024-09-29 08:00:38,233 - INFO - Successfully generated 2024 - Assignment 2 - A1-23136008.csv
# 2024-09-29 08:00:38,291 - INFO - Successfully generated 2024 - Assignment 2 - A1-23136009.csv
# 2024-09-29 08:00:38,373 - INFO - Successfully generated 2024 - Assignment 2 - A1-23136010.csv
# 2024-09-29 08:00:38,432 - INFO - Successfully generated 2024 - Assignment 2 - A1-23136011.csv
# 2024-09-29 08:00:38,492 - INFO - Successfully generated 2024 - Assignment 2 - A1-23136012.csv
# 2024-09-29 08:00:38,533 - INFO - Successfully generated 2024 - Assignment 2 - A1-23136013.csv
# 2024-09-29 08:00:38,586 - INFO - Successfully generated 2024 - Assignment 2 - A1-23136014.csv
# 2024-09-29 08:00:38,658 - INFO - Successfully generated 2024 - Assignment 2 - A1-23136015.csv
# 2024-09-29 08:00:38,758 - INFO - Successfully generated 2024 - Assignment 2 - A1-23136016.csv
